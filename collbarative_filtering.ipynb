# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelB26/ICTAK/blob/main/collbarative_filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
ratings=pd.read_csv('u.data',sep='\t')

# %%
ratings.head()
# Out:
#    196  242  3  881250949
# 0  186  302  3  891717742
# 1   22  377  1  878887116
# 2  244   51  2  880606923
# 3  166  346  1  886397596
# 4  298  474  4  884182806

# %%
col=['user_id','movie_id','ratings','timestamp']

# %%
ratings=pd.read_csv('u.data',sep='\t',names=col)

# %%
ratings.head()
# Out:
#    user_id  movie_id  ratings  timestamp
# 0      196       242        3  881250949
# 1      186       302        3  891717742
# 2       22       377        1  878887116
# 3      244        51        2  880606923
# 4      166       346        1  886397596

# %%
ratings['user_id'].nunique()
# Out:
# 943

# %%
ratings['movie_id'].nunique()
# Out:
# 1682

# %%
ratings.shape
# Out:
# (100000, 4)

# %%
ratings.drop('timestamp',axis=1,inplace=True)

# %%
ratings.head()
# Out:
#    user_id  movie_id  ratings
# 0      196       242        3
# 1      186       302        3
# 2       22       377        1
# 3      244        51        2
# 4      166       346        1

# %%
pip install surprise
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3162663 sha256=0439961980870eb6d11c37698d9490bbc761d597a94559bf413d8de3901367cd
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# ...

# %%
from surprise import Dataset,Reader,KNNBasic,SVD

# %%
ratings['ratings'].unique()
# Out:
# array([3, 1, 2, 4, 5])

# %%
reader=Reader(rating_scale=(1,5))

# %%
data=Dataset.load_from_df(ratings,reader)

# %%
algo=KNNBasic()

# %%
from surprise.model_selection import cross_validate

# %%
cross_validate(algo,data,measures=['RMSE'],cv=5)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# {'test_rmse': array([0.97963678, 0.98072717, 0.97557233, 0.9812806 , 0.9820513 ]),
#  'fit_time': (0.4252586364746094,
#   0.3700408935546875,
#   0.35979270935058594,
#   0.3499734401702881,
#   0.3476376533508301),
#  'test_time': (3.862628221511841,
#   3.2063775062561035,
#   3.414719820022583,
#   3.8847579956054688,
#   3.135350465774536)}

# %%
algo2=SVD()

# %%
cross_validate(algo2,data,measures=['RMSE'],cv=5)
# Out:
# {'test_rmse': array([0.93835777, 0.93554002, 0.93754364, 0.93156405, 0.93680717]),
#  'fit_time': (1.4280283451080322,
#   1.4662365913391113,
#   1.7076184749603271,
#   1.9075419902801514,
#   1.4745593070983887),
#  'test_time': (0.12558507919311523,
#   0.25069379806518555,
#   0.1922140121459961,
#   0.14455795288085938,
#   0.27220678329467773)}
