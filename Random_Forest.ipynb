# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelB26/ICTAK/blob/main/Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/Heart.csv')

# %%
data.head()
# Out:
#    Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   63    1          3     145   233    1        2    150      0      2.3
# 1   67    1          0     160   286    0        2    108      1      1.5
# 2   67    1          0     120   229    0        2    129      1      2.6
# 3   37    1          1     130   250    0        0    187      0      3.5
# 4   41    0          2     130   204    0        2    172      0      1.4
#
#    Slope  Ca  AHD
# 0      3   0    0
# 1      2   3    1
# 2      2   2    1
# 3      3   0    0
# 4      1   0    0

# %%
#creating x and y

# %%
x=data.drop('AHD',axis=1)
y=data.AHD

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 294    1
# 295    1
# 296    1
# 297    1
# 298    1
# Name: AHD, Length: 299, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7333333333333333

# %%
from sklearn import tree
plt.figure(figsize=(20,9))
tree.plot_tree(clf)
plt.show()

# %%
#random Forest
from sklearn.ensemble import RandomForestClassifier

# %%
clf=RandomForestClassifier(n_estimators=100)

# %%
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=clf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8266666666666667

# %%
#ADAboost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
clf=AdaBoostClassifier(n_estimators=100)

# %%
clf=clf.fit(x_train,y_train)

# %%
y_pred=clf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.68
